# %%
from utils import *
from simulations import *
from simulation_script import run_simulation_series
import params
stretch_simulations = [params.stretch_global_params, params.stretch_modular_params, params.stretch_local_params]
shear_simulations = [params.shear_global_params, params.shear_modular_params, params.shear_local_params]


run_simulation_series(n_sim_round=13, distortion_params_list=shear_simulations, plot_sim_trajectories=False, save_data=False, save_plots=True)
# Out:
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ RUNNING SIMULATIONS FOR DISTORTION=shear-global-1 -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# Loading previously simulated results from simulation_outputs/round-13/global/nm_trials-100_shear-global_a-0_b-0.pkl
# Loading previously simulated results from simulation_outputs/round-13/global/dcm_trials-100_shear-global_a-0_b-0.pkl
# Loading previously simulated results from simulation_outputs/round-13/global/vcm_trials-100_shear-global_a-0_b-0.pkl
#
#  -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ RUNNING SIMULATIONS FOR DISTORTION=shear-global-2 -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# Loading previously simulated results from simulation_outputs/round-13/global/nm_trials-100_shear-global_a-0_b-1.pkl
# Loading previously simulated results from simulation_outputs/round-13/global/dcm_trials-100_shear-global_a-0_b-1.pkl
# ...
